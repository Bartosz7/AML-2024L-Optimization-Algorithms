# %%
import numpy as np
from datasets import *
from optim import GD, ADAM, IWLS

# %%
from utils.train_functions import cv
from utils.plots import (
    plot_figures_for_cv,
    plot_acc_boxplots
)

# %%
dataset_names = [
    "booking", "churn", "diabetes", "employee", "challenger", "jungle", "ionosphere", "water", "seeds", "sonar"
]
datasets = {
    name: load_dataset(name) for name in dataset_names
}

# %% [markdown]
# # Employee

# %%
employee_l_vals, employee_acc = cv(datasets["employee"], n_splits=5)
# Out:
# CV split 1
# Removing multicolinear columns in employee dataset...
# Finished
# ...
# ADAM:   8%|▊         | 41/500 [00:06<01:11,  6.41it/s]
# CV split 2
# Removing multicolinear columns in employee dataset...
# Finished
# ...
# ADAM:   8%|▊         | 38/500 [00:06<01:13,  6.31it/s]
# CV split 3
# Removing multicolinear columns in employee dataset...
# Finished
# ...
# ADAM:   7%|▋         | 34/500 [00:05<01:09,  6.70it/s]
# CV split 4
# Removing multicolinear columns in employee dataset...
# Finished
# ...
# ADAM:   8%|▊         | 41/500 [00:05<01:06,  6.86it/s]
# CV split 5
# Removing multicolinear columns in employee dataset...
# Finished
# ...
# ADAM:   6%|▌         | 30/500 [00:04<01:11,  6.53it/s]

# %%
plot_acc_boxplots(employee_acc)

# %%
plot_figures_for_cv(employee_l_vals["iwls"], employee_l_vals["sgd"], employee_l_vals["adam"])

# %%
first_split_l_vals = {
    "iwls": employee_l_vals["iwls"][0],
    "sgd": employee_l_vals["sgd"][0],
    "adam": employee_l_vals["adam"][0]
}

# %%
from utils.plots import plot_loss_convergence

plot_loss_convergence(first_split_l_vals)

# %% [markdown]
# # Challenger

# %%
challenger_l_vals, challenger_acc = cv(datasets["challenger"], n_splits=5)
# Out:
# CV split 1
# Removing multicolinear columns in challenger_lol dataset...
# ...
# ADAM:   2%|▏         | 12/500 [00:08<06:03,  1.34it/s]
# CV split 2
# Removing multicolinear columns in challenger_lol dataset...
# ...
# ADAM:   2%|▏         | 12/500 [00:08<06:02,  1.35it/s]
# CV split 3
# Removing multicolinear columns in challenger_lol dataset...
# ...
# ADAM:   2%|▏         | 12/500 [00:08<06:01,  1.35it/s]
# CV split 4
# Removing multicolinear columns in challenger_lol dataset...
# ...
# ADAM:   2%|▏         | 12/500 [00:09<06:08,  1.32it/s]
# CV split 5
# Removing multicolinear columns in challenger_lol dataset...
# ...
# ADAM:   2%|▏         | 12/500 [00:08<05:56,  1.37it/s]

# %%
plot_acc_boxplots(challenger_acc)

# %%
plot_figures_for_cv(challenger_l_vals["iwls"], challenger_l_vals["sgd"], challenger_l_vals["adam"])

# %% [markdown]
# # Jungle

# %%
jungle_l_vals, jungle_acc = cv(datasets["jungle"], n_splits=5)
# Out:
# CV split 1
# Removing multicolinear columns in jungle dataset...
# ...
# ADAM:  66%|██████▌   | 329/500 [00:47<00:24,  6.94it/s]
# CV split 2
# Removing multicolinear columns in jungle dataset...
# ...
# ADAM:  80%|████████  | 400/500 [00:58<00:14,  6.87it/s]
# CV split 3
# Removing multicolinear columns in jungle dataset...
# ...
# ADAM:  63%|██████▎   | 317/500 [00:43<00:25,  7.26it/s]
# CV split 4
# Removing multicolinear columns in jungle dataset...
# ...
# ADAM:  94%|█████████▍| 471/500 [01:07<00:04,  6.96it/s]
# CV split 5
# Removing multicolinear columns in jungle dataset...
# ...
# ADAM:  79%|███████▊  | 393/500 [00:56<00:15,  6.95it/s]

# %%
plot_acc_boxplots(jungle_acc)

# %%
plot_figures_for_cv(jungle_l_vals["iwls"], jungle_l_vals["sgd"], jungle_l_vals["adam"])

# %% [markdown]
# # Employee (with interactions)

# %%
employee_inter_l_vals, employee_inter_acc = cv(datasets["employee"], n_splits=5, interactions=True)
# Out:
# CV split 1
# Removing multicolinear columns in employee dataset...
# ...
# ADAM:  15%|█▌        | 75/500 [00:11<01:03,  6.72it/s]
# CV split 2
# Removing multicolinear columns in employee dataset...
# ...
# ADAM:  20%|█▉        | 98/500 [00:14<00:58,  6.88it/s]
# CV split 3
# Removing multicolinear columns in employee dataset...
# ...
# ADAM:  18%|█▊        | 88/500 [00:13<01:03,  6.44it/s]
# CV split 4
# Removing multicolinear columns in employee dataset...
# ...
# ADAM:   5%|▌         | 25/500 [00:03<01:11,  6.61it/s]
# CV split 5
# Removing multicolinear columns in employee dataset...
# ...
# ADAM:  14%|█▍        | 69/500 [00:10<01:06,  6.53it/s]

# %%
plot_acc_boxplots(employee_inter_acc)

# %%
plot_figures_for_cv(jungle_l_vals["iwls"], jungle_l_vals["sgd"], jungle_l_vals["adam"])

# %% [markdown]
# # Jungle (with interactions)

# %%
jungle_inter_l_vals, jungle_inter_acc = cv(datasets["jungle"], n_splits=5, interactions=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 jungle_inter_l_vals, jungle_inter_acc = cv(datasets["jungle"], n_splits=5, interactions=True)
#
# NameError: name 'cv' is not defined

# %%
plot_acc_boxplots(jungle_inter_acc)

# %%
plot_figures_for_cv(jungle_inter_l_vals["iwls"], jungle_inter_l_vals["sgd"], jungle_inter_l_vals["adam"])

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 17
#       9     fig.update_layout(title='Loss Convergence',
#      10                       xaxis_title='Epoch',
#      11                       yaxis_title='Loss',
#      12                       legend_title='Optimizer',
#      13                       template='plotly_white')
#      15     fig.show()
# ---> 17 plot_loss_convergence(jungle_inter_l_vals)
#
# Cell In[23], line 15, in plot_loss_convergence(loss_dict)
#       7     fig.add_trace(go.Scatter(x=list(range(1, len(losses)+1)), y=losses, mode='lines+markers', name=optimizer))
#       9 fig.update_layout(title='Loss Convergence',
#      10                   xaxis_title='Epoch',
#      11                   yaxis_title='Loss',
#      12                   legend_title='Optimizer',
#      13                   template='plotly_white')
# ---> 15 fig.show()
#
# ...
